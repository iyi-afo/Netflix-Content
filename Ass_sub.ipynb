# %%
import pandas as pd

# %%
Netflix = pd.read_csv(r"C:\Users\DELL\Downloads\Dataset\netflix_titles.csv")

# %%
Netflix.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
Netflix.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
Netflix['country'] = Netflix['country'].fillna("Unknown")
Netflix
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
Netflix['type'].value_counts()
# Out:
# type
# Movie      6131
# TV Show    2676
# Name: count, dtype: int64

# %%
Netflix_country_counts = Netflix['country'].value_counts()
Netflix_country_counts
# Out:
# country
# United States                                             2818
# India                                                      972
# Unknown                                                    831
# United Kingdom                                             419
# Japan                                                      245
#                                                           ...
# Germany, Canada, United States                               1
# Denmark, United Kingdom, South Africa, Sweden, Belgium       1
# Serbia, South Korea, Slovenia                                1
# United Kingdom, Spain, Belgium                               1
# South Africa, United States, Japan                           1
# Name: count, Length: 749, dtype: int64

# %%
Top_10_countries = Netflix_country_counts.head(10)

# %%
Top_10_countries
# Out:
# country
# United States     2818
# India              972
# Unknown            831
# United Kingdom     419
# Japan              245
# South Korea        199
# Canada             181
# Spain              145
# France             124
# Mexico             110
# Name: count, dtype: int64

# %%
Netflix['date_added'] = Netflix['date_added'].str.strip()

# %%
Netflix['date_added'] = pd.to_datetime(Netflix['date_added'])
Netflix
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
Netflix['year_added'] = Netflix['date_added'].dt.year

# %%
Netflix
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
import numpy as np

# %%
Movie_before_2000 = Netflix[Netflix['release_year'] < 2000]
Movie_before_2000
# Out:
#      show_id   type                                title          director  \
# 7         s8  Movie                              Sankofa      Haile Gerima
# 22       s23  Movie                      Avvai Shanmughi    K.S. Ravikumar
# 24       s25  Movie                                Jeans        S. Shankar
# 26       s27  Movie                       Minsara Kanavu       Rajiv Menon
# 41       s42  Movie                                 Jaws  Steven Spielberg
# ...      ...    ...                                  ...               ...
# 8745   s8746  Movie  Willy Wonka & the Chocolate Factory        Mel Stuart
# 8748   s8749  Movie                 Winter of Our Dreams       John Duigan
# 8763   s8764  Movie      WWII: Report from the Aleutians       John Huston
# 8764   s8765  Movie                           Wyatt Earp   Lawrence Kasdan
# 8792   s8793  Movie                          Young Tiger            Mu Chu
#
#                                                    cast  \
# ...

# %%
Most_Common_Genre = Netflix['listed_in'].value_counts().idxmax()
Most_Common_Genre
# Out:
# 'Dramas, International Movies'

# %%
Rajkumar_shows = Netflix[Netflix['director'] == 'Rajkumar Hirani']
Rajkumar_shows
# Out:
#      show_id   type     title         director  \
# 1114   s1115  Movie  3 Idiots  Rajkumar Hirani
# 4507   s4508  Movie     Sanju  Rajkumar Hirani
# 4660   s4661  Movie        PK  Rajkumar Hirani
#
#                                                    cast country date_added  \
# 1114  Aamir Khan, Kareena Kapoor, Madhavan, Sharman ...   India 2021-04-01
# 4507  Ranbir Kapoor, Vicky Kaushal, Paresh Rawal, So...   India 2018-10-15
# 4660  Aamir Khan, Anuskha Sharma, Sanjay Dutt, Saura...   India 2018-09-06
#
#       release_year rating duration                               listed_in  \
# 1114          2009  PG-13  164 min  Comedies, Dramas, International Movies
# 4507          2018  TV-MA  159 min            Dramas, International Movies
# 4660          2014  TV-14  146 min  Comedies, Dramas, International Movies
#
#                                             description  year_added
# 1114  While attending one of India's premier college...      2021.0
# ...

# %%
rating_counts = Netflix['rating'].value_counts()
rating_counts
# Out:
# rating
# TV-MA       3207
# TV-14       2160
# TV-PG        863
# R            799
# PG-13        490
# TV-Y7        334
# TV-Y         307
# PG           287
# TV-G         220
# NR            80
# G             41
# TV-Y7-FV       6
# NC-17          3
# UR             3
# 74 min         1
# 84 min         1
# 66 min         1
# Name: count, dtype: int64

# %%
Movies = Netflix[Netflix['type'] == 'Movie']
Movies
# Out:
#      show_id   type                             title  \
# 0         s1  Movie              Dick Johnson Is Dead
# 6         s7  Movie  My Little Pony: A New Generation
# 7         s8  Movie                           Sankofa
# 9        s10  Movie                      The Starling
# 12       s13  Movie                      Je Suis Karl
# ...      ...    ...                               ...
# 8801   s8802  Movie                           Zinzana
# 8802   s8803  Movie                            Zodiac
# 8804   s8805  Movie                        Zombieland
# 8805   s8806  Movie                              Zoom
# 8806   s8807  Movie                            Zubaan
#
#                            director  \
# 0                   Kirsten Johnson
# 6     Robert Cullen, José Luis Ucha
# 7                      Haile Gerima
# 9                    Theodore Melfi
# 12              Christian Schwochow
# ...                             ...
# 8801                Majid Al Ansari
# ...

# %%
Movies_over_100mins = Movies[Movies['duration_minutes'] > 100]
Movies_over_100mins
# Out:
# Empty DataFrame
# Columns: [show_id, type, title, director, cast, country, date_added, release_year, rating, duration, listed_in, description, year_added, duration_minutes]
# Index: []

# %%
Netflix.to_csv('Netflix_cleaned.csv', index
